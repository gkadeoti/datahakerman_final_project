# %%
import pandas as pd
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
pd.options.display.max_colwidth = None
pd.set_option("display.float_format", lambda x: '%.2f' % x)

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import requests

# %%
got_characters_url="https://www.anapioficeandfire.com/api/characters"
query_params = {"index":"<=40", "gender": "male"}
requests.get(got_characters_url, query_params)
# Out:
# <Response [200]>

# %%
index_40_male= requests.get(got_characters_url, query_params)

# %%
index_40_male.json()
# Out:
# [{'url': 'https://www.anapioficeandfire.com/api/characters/2',
#   'name': 'Walder',
#   'gender': 'Male',
#   'culture': '',
#   'born': '',
#   'died': '',
#   'titles': [''],
#   'aliases': ['Hodor'],
#   'father': '',
#   'mother': '',
#   'spouse': '',
#   'allegiances': ['https://www.anapioficeandfire.com/api/houses/362'],
#   'books': ['https://www.anapioficeandfire.com/api/books/1',
#    'https://www.anapioficeandfire.com/api/books/2',
#    'https://www.anapioficeandfire.com/api/books/3',
#    'https://www.anapioficeandfire.com/api/books/5',
#    'https://www.anapioficeandfire.com/api/books/8'],
#   'povBooks': [],
#   'tvSeries': ['Season 1', 'Season 2', 'Season 3', 'Season 4', 'Season 6'],
#   'playedBy': ['Kristian Nairn']},
#  {'url': 'https://www.anapioficeandfire.com/api/characters/3',
#   'name': '',
#   'gender': 'Male',
#   'culture': '',
#   'born': '',
#   'died': '',
#   'titles': [''],
#   'aliases': ['Lamprey'],
#   'father': '',
#   'mother': '',
# ...

# %%
index_40_male_data = pd.DataFrame(index_40_male.json())

# %%
index_25_male_data
# Out:
#                                                    url           name gender
# 0   https://www.anapioficeandfire.com/api/characters/2         Walder   Male  \
# 1   https://www.anapioficeandfire.com/api/characters/3                  Male
# 2   https://www.anapioficeandfire.com/api/characters/5                  Male
# 3   https://www.anapioficeandfire.com/api/characters/8                  Male
# 4  https://www.anapioficeandfire.com/api/characters/12  Balon Greyjoy   Male
# 5  https://www.anapioficeandfire.com/api/characters/13         Chayle   Male
# 6  https://www.anapioficeandfire.com/api/characters/14         Gillam   Male
# 7  https://www.anapioficeandfire.com/api/characters/15    High Septon   Male
# 8  https://www.anapioficeandfire.com/api/characters/18       Meribald   Male
# 9  https://www.anapioficeandfire.com/api/characters/22        Ollidor   Male
#
#   culture                                    born                      died
# ...

# %%
characters_url="https://www.anapioficeandfire.com/api/characters"
query_params = {"index":"<=15", "gender": "male"}
requests.get(characters_url, query_params)
# Out:
# <Response [200]>

# %%
index_15_male = requests.get(characters_url, query_params)

# %%
index_15_male.json()
# Out:
# [{'url': 'https://www.anapioficeandfire.com/api/characters/2',
#   'name': 'Walder',
#   'gender': 'Male',
#   'culture': '',
#   'born': '',
#   'died': '',
#   'titles': [''],
#   'aliases': ['Hodor'],
#   'father': '',
#   'mother': '',
#   'spouse': '',
#   'allegiances': ['https://www.anapioficeandfire.com/api/houses/362'],
#   'books': ['https://www.anapioficeandfire.com/api/books/1',
#    'https://www.anapioficeandfire.com/api/books/2',
#    'https://www.anapioficeandfire.com/api/books/3',
#    'https://www.anapioficeandfire.com/api/books/5',
#    'https://www.anapioficeandfire.com/api/books/8'],
#   'povBooks': [],
#   'tvSeries': ['Season 1', 'Season 2', 'Season 3', 'Season 4', 'Season 6'],
#   'playedBy': ['Kristian Nairn']},
#  {'url': 'https://www.anapioficeandfire.com/api/characters/3',
#   'name': '',
#   'gender': 'Male',
#   'culture': '',
#   'born': '',
#   'died': '',
#   'titles': [''],
#   'aliases': ['Lamprey'],
#   'father': '',
#   'mother': '',
# ...

# %%
index_15_male_data = pd.DataFrame(index_15_male.json())

# %%
index_15_male_data
# Out:
#                                                    url           name gender
# 0   https://www.anapioficeandfire.com/api/characters/2         Walder   Male  \
# 1   https://www.anapioficeandfire.com/api/characters/3                  Male
# 2   https://www.anapioficeandfire.com/api/characters/5                  Male
# 3   https://www.anapioficeandfire.com/api/characters/8                  Male
# 4  https://www.anapioficeandfire.com/api/characters/12  Balon Greyjoy   Male
# 5  https://www.anapioficeandfire.com/api/characters/13         Chayle   Male
# 6  https://www.anapioficeandfire.com/api/characters/14         Gillam   Male
# 7  https://www.anapioficeandfire.com/api/characters/15    High Septon   Male
# 8  https://www.anapioficeandfire.com/api/characters/18       Meribald   Male
# 9  https://www.anapioficeandfire.com/api/characters/22        Ollidor   Male
#
#   culture                                    born                      died
# ...
